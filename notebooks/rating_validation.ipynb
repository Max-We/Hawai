# %%
import pandas as pd

from config import RATINGS_FILE

df = pd.read_csv("../"+RATINGS_FILE)

# %%
df.head()
# Out:
#                                    uuid  item_id  rating  \
# 0  9dcc269d-e8b6-44e5-9214-76d9b98d236c    90323       2
# 1  9dcc269d-e8b6-44e5-9214-76d9b98d236c    43806       2
# 2  9dcc269d-e8b6-44e5-9214-76d9b98d236c    41168      -1
# 3  9dcc269d-e8b6-44e5-9214-76d9b98d236c      519       1
# 4  9dcc269d-e8b6-44e5-9214-76d9b98d236c    28383       1
#
#                                           item_title  \
# 0                                        garlic loaf
# 1  chicken coconut curry soup   a k a  easy mulli...
# 2                       cherry almond butter cookies
# 3              second only to my meatloaf  meatballs
# 4                       breakfast  pizza   somersize
#
#                                     item_ingredients
# 0  ['butter', 'parsley', 'garlic powder', 'garlic...
# 1  ['whole boneless skinless chicken breast', 'po...
# 2  ['butter', 'sugar', 'egg', 'vanilla', 'flour',...
# 3  ['ground beef', 'oatmeal', 'onion', 'egg', 'mi...
# 4  ['bulk sausage', 'cheddar cheese', 'eggs', 'di...

# %%
df["uuid_trunc"] = df["uuid"].apply(lambda x: x[:5])
df["item_title"] = df["item_title"].apply(lambda x: x[:10])
df["rating"] = df["rating"].astype(float)

# %%
# plot ratings for each user as bar plot
df.groupby("uuid_trunc")["rating"].var().plot.bar()
# Out:
# <Axes: xlabel='uuid_trunc'>

# %%
# nr. of unique items rated
df["item_title"].nunique()
# Out:
# 33

# %%
# plot variance ratings for each item ad bar plot
df.groupby("item_title")["rating"].var().plot.bar()
# Out:
# <Axes: xlabel='item_title'>

# %%
# plot rating distribution overall (integer x-axis)
df["rating"].plot.hist(bins=5)
# Out:
# <Axes: ylabel='Frequency'>
