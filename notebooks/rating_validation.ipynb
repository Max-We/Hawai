# %%
import pandas as pd

from config import RATINGS_FILE

df = pd.read_csv("../"+RATINGS_FILE)

# %%
df.head()
# Out:
#                                    uuid  item_id  rating  \
# 0  5308beca-969f-4bbc-adf5-c5954da9cf4b   135116       0
# 1  5308beca-969f-4bbc-adf5-c5954da9cf4b    92016       2
# 2  5308beca-969f-4bbc-adf5-c5954da9cf4b    38953       1
# 3  5308beca-969f-4bbc-adf5-c5954da9cf4b   166030      -1
# 4  5308beca-969f-4bbc-adf5-c5954da9cf4b    89503       0
#
#                              item_title  \
# 0                  microwave crab puffs
# 1              ginger green onion sauce
# 2  cheddar crust granny smith apple pie
# 3               prince of wales cake iv
# 4             gabbie s sweet potato pie
#
#                                     item_ingredients
# 0  ['crabmeat', 'mayonnaise', 'onions', 'prepared...
# 1    ['green onion', 'ginger', 'salt', 'sesame oil']
# 2  ['all-purpose flour', 'salt', 'butter', 'sharp...
# 3  ['butter', 'light brown sugar', 'eggs', 'butte...
# 4  ['sweet potatoes', 'sugar', 'eggs', 'butter', ...

# %%
df["uuid_trunc"] = df["uuid"].apply(lambda x: x[:5])
df["item_title"] = df["item_title"].apply(lambda x: x[:10])
df["rating"] = df["rating"].astype(float)

# %%
# plot ratings for each user as bar plot
df.groupby("uuid_trunc")["rating"].var().plot.bar()
# Out:
# <Axes: xlabel='uuid_trunc'>

# %%
# nr. of unique items rated
df["item_title"].nunique()
# Out:
# 140

# %%
# plot variance ratings for each item ad bar plot
df.groupby("item_title")["rating"].var().plot.bar()
# Out:
# <Axes: xlabel='item_title'>

# %%
# plot rating distribution overall (integer x-axis)
df["rating"].plot.hist(bins=5)
# Out:
# <Axes: ylabel='Frequency'>
