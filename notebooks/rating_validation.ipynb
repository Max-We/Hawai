# %%
import pandas as pd

from config import RATINGS_FILE

df = pd.read_csv("../"+RATINGS_FILE)

# %%
df.head()
# Out:
#                                    uuid  item_id  rating  \
# 0  9dcc269d-e8b6-44e5-9214-76d9b98d236c    70868       0
# 1  9dcc269d-e8b6-44e5-9214-76d9b98d236c    14468       2
# 2  9dcc269d-e8b6-44e5-9214-76d9b98d236c    57629       1
# 3  9dcc269d-e8b6-44e5-9214-76d9b98d236c    17528       2
# 4  9dcc269d-e8b6-44e5-9214-76d9b98d236c    32740       0
#
#                        item_title  \
# 0  delicious dill dip for veggies
# 1    baked lamb chops and lentils
# 2  copycat campbell s tomato soup
# 3             barbecue baked fish
# 4       butterscotch velvet sauce
#
#                                     item_ingredients
# 0  ['mayonnaise', 'sour cream', 'dill weed', 'oni...
# 1  ['lamb chops', 'dried rosemary', 'garlic', 'br...
# 2  ['tomato sauce', 'tomato paste', 'water', 'gar...
# 3  ['catfish fillets', 'ketchup', 'barbecue sauce...
# 4  ['brown sugar', 'strong coffee', 'butter', 'sa...

# %%
df["uuid_trunc"] = df["uuid"].apply(lambda x: x[:5])
df["item_title"] = df["item_title"].apply(lambda x: x[:10])
df["rating"] = df["rating"].astype(float)

# %%
# plot ratings for each user as bar plot
df.groupby("uuid_trunc")["rating"].var().plot.bar()
# Out:
# <Axes: xlabel='uuid_trunc'>

# %%
# nr. of unique items rated
df["item_title"].nunique()
# Out:
# 143

# %%
# plot variance ratings for each item ad bar plot
df.groupby("item_title")["rating"].var().plot.bar()
# Out:
# <Axes: xlabel='item_title'>

# %%
# plot rating distribution overall (integer x-axis)
df["rating"].plot.hist(bins=5)
# Out:
# <Axes: ylabel='Frequency'>
